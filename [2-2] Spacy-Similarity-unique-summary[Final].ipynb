# %%
import re
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, PorterStemmer
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
from tqdm import tqdm

# %% [markdown]
# ### Data Load

# %%
df = pd.read_csv('IMDB/dataset/spacy-pre-sum_syn.csv')

# %%
df
# Out:
#          movie_id     user_id  is_spoiler  \
# 0       tt0111161   ur0842118        True
# 1       tt0111161   ur6574726        True
# 2       tt0111161  ur31182745        True
# 3       tt0111161   ur9871443        True
# 4       tt0111161  ur23169472        True
# ...           ...         ...         ...
# 257274  tt0139239   ur0415521       False
# 257275  tt0139239   ur0100166       False
# 257276  tt0139239   ur0021767       False
# 257277  tt0139239   ur0349105       False
# 257278  tt0139239   ur0156431       False
#
#                                                    review  \
# 0       shawshank redempt without doubt one brilliant ...
# 1       fan long ever time life hit downward spiral al...
# 2       made account rate heard someon tim robin done ...
# 3       friend mine list shawshank redempt one time fa...
# 4       tell truth speechless young fanat fact film ca...
# ...                                                   ...
# 257274  type one ordinarili see howev becom acquaint a...
# 257275  go wise fast pure entertain assembl except cas...
# 257276  well shall say fun rate three plotlin origin o...
# 257277  call teenag version pulp fiction whatev pleas ...
# 257278  made doubt sucker mtv faith care anyth exterio...
#
#                                                   summary  \
# 0       chronicl experi former success banker prison g...
# 1       chronicl experi former success banker prison g...
# 2       chronicl experi former success banker prison g...
# 3       chronicl experi former success banker prison g...
# 4       chronicl experi former success banker prison g...
# ...                                                   ...
# 257274  told three perspect stori bunch young californ...
# 257275  told three perspect stori bunch young californ...
# 257276  told three perspect stori bunch young californ...
# 257277  told three perspect stori bunch young californ...
# 257278  told three perspect stori bunch young californ...
#
#                                                  synopsis
# 0       andi said larg black stone meanwhil remain ste...
# 1       andi said larg black stone meanwhil remain ste...
# 2       andi said larg black stone meanwhil remain ste...
# 3       andi said larg black stone meanwhil remain ste...
# 4       andi said larg black stone meanwhil remain ste...
# ...                                                   ...
# 257274  ronna lie motionless storyearli recruit cover ...
# 257275  ronna lie motionless storyearli recruit cover ...
# 257276  ronna lie motionless storyearli recruit cover ...
# 257277  ronna lie motionless storyearli recruit cover ...
# 257278  ronna lie motionless storyearli recruit cover ...
#
# [257279 rows x 6 columns]

# %%
df['review'].replace('', np.nan, inplace=True)
df.dropna(subset=['review'], inplace=True)

df['summary'].replace('', np.nan, inplace=True)
df.dropna(subset=['summary'], inplace=True)


df['synopsis'].replace('', np.nan, inplace=True)
df.dropna(subset=['synopsis'], inplace=True)

# %%
df_1 = df.iloc[1:150000]
df_2 = df.iloc[150000:]

# %%
df_1
# Out:
#          movie_id     user_id  is_spoiler  \
# 1       tt0111161   ur6574726        True
# 2       tt0111161  ur31182745        True
# 3       tt0111161   ur9871443        True
# 4       tt0111161  ur23169472        True
# 5       tt0111161  ur34426359        True
# ...           ...         ...         ...
# 149995  tt0259446   ur0470000       False
# 149996  tt0259446   ur1630682       False
# 149997  tt0259446   ur0599255       False
# 149998  tt0259446   ur1923367       False
# 149999  tt0259446   ur0664492       False
#
#                                                    review  \
# 1       fan long ever time life hit downward spiral al...
# 2       made account rate heard someon tim robin done ...
# 3       friend mine list shawshank redempt one time fa...
# 4       tell truth speechless young fanat fact film ca...
# 5       wow film babi one brilliant ever written man l...
# ...                                                   ...
# 149995  plod romant comedi pace spark whatsoev begrudg...
# 149996  see love greek cultur made high spirit saw mom...
# 149997  let face put titl recept critic thought adam s...
# 149998  partner saw big fat greek wed local know expec...
# 149999  greek woman nia vardalo thirti decid marri man...
#
#                                                   summary  \
# 1       chronicl experi former success banker prison g...
# 2       chronicl experi former success banker prison g...
# 3       chronicl experi former success banker prison g...
# 4       chronicl experi former success banker prison g...
# 5       chronicl experi former success banker prison g...
# ...                                                   ...
# 149995  toula portokalo greek work famili restaur danc...
# 149996  toula portokalo greek work famili restaur danc...
# 149997  toula portokalo greek work famili restaur danc...
# 149998  toula portokalo greek work famili restaur danc...
# 149999  toula portokalo greek work famili restaur danc...
#
#                                                  synopsis
# 1       andi said larg black stone meanwhil remain ste...
# 2       andi said larg black stone meanwhil remain ste...
# 3       andi said larg black stone meanwhil remain ste...
# 4       andi said larg black stone meanwhil remain ste...
# 5       andi said larg black stone meanwhil remain ste...
# ...                                                   ...
# 149995  gus start invit greek men dinner toula part so...
# 149996  gus start invit greek men dinner toula part so...
# 149997  gus start invit greek men dinner toula part so...
# 149998  gus start invit greek men dinner toula part so...
# 149999  gus start invit greek men dinner toula part so...
#
# [149999 rows x 6 columns]

# %%
similarityValue = []

for i in tqdm(range(df_1.count()[0])):
    sentence_1 = nlp(df_1.iloc[i][3])
    sentence_2 = nlp(df_1.iloc[i][4])
    similarityValue.append(sentence_1.similarity(sentence_2))

df_1['summary_sim'] = similarityValue
# Out:
#  12%|█████████                                                                  | 18182/149999 [04:01<28:50, 76.18it/s]C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:6: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#
# 100%|██████████████████████████████████████████████████████████████████████████| 149999/149999 [34:47<00:00, 71.85it/s]
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
similarityValue = []

for i in tqdm(range(df_2.count()[0])):
    sentence_1 = nlp(df_2.iloc[i][3])
    sentence_2 = nlp(df_2.iloc[i][4])
    similarityValue.append(sentence_1.similarity(sentence_2))

df_2['summary_sim'] = similarityValue
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 107278/107278 [25:17<00:00, 70.70it/s]
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# review - synopsis similarity (1)
similarityValue = []

for i in tqdm(range(df_1.count()[0])):
    sentence_1 = nlp(df_1.iloc[i][3])
    sentence_2 = nlp(df_1.iloc[i][5])
    similarityValue.append(sentence_1.similarity(sentence_2))

df_1['synopsis_sim'] = similarityValue
# Out:
#  12%|████████▊                                                                | 18184/149999 [12:51<1:12:27, 30.32it/s]C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:7: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   import sys
# 100%|████████████████████████████████████████████████████████████████████████| 149999/149999 [1:27:19<00:00, 28.63it/s]
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# review - synopsis similarity (2)
similarityValue = []

for i in tqdm(range(df_2.count()[0])):
    sentence_1 = nlp(df_2.iloc[i][3])
    sentence_2 = nlp(df_2.iloc[i][4])
    similarityValue.append(sentence_1.similarity(sentence_2))

df_2['synopsis_sim'] = similarityValue
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 107278/107278 [25:13<00:00, 70.86it/s]
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_1.to_csv('IMDB/dataset/sim1-spacy-pre-unq.csv', index= False)

# %%
df_2.to_csv('IMDB/dataset/sim2-spacy-pre-unq.csv', index= False)
