# %%
import re
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, PorterStemmer
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
from tqdm import tqdm

# %% [markdown]
# ### Data Load

# %%
df = pd.read_csv('IMDB/dataset/spacy-pre.csv')

# %%
df
# Out:
#          movie_id    user_id  is_spoiler  \
# 0       tt0111161  ur1898687        True
# 1       tt0111161  ur0842118        True
# 2       tt0111161  ur1285640        True
# 3       tt0111161  ur1003471        True
# 4       tt0111161  ur0226855        True
# ...           ...        ...         ...
# 538823  tt0139239  ur0100166       False
# 538824  tt0139239  ur0021767       False
# 538825  tt0139239  ur0392750       False
# 538826  tt0139239  ur0349105       False
# 538827  tt0139239  ur0156431       False
#
#                                                    review  \
# 0       oscar year shawshank redempt written direct fr...
# 1       shawshank redempt without doubt one brilliant ...
# 2       believ film best stori ever told film tell rob...
# 3       yes spoiler film emot impact find hard write c...
# 4       heart extraordinari movi brilliant indel perfo...
# ...                                                   ...
# 538823  go wise fast pure entertain assembl except cas...
# 538824  well shall say fun rate three plotlin origin o...
# 538825  go best movi ever seen seen lot movi read revi...
# 538826  call teenag version pulp fiction whatev want p...
# 538827  movi made doubt sucker mtv faith mani care any...
#
#                                                  synopsis
# 0       andi dufresn tim robbin banker main convict mu...
# 1       andi dufresn tim robbin banker main convict mu...
# 2       andi dufresn tim robbin banker main convict mu...
# 3       andi dufresn tim robbin banker main convict mu...
# 4       andi dufresn tim robbin banker main convict mu...
# ...                                                   ...
# 538823  film told chronolog format stori told four dif...
# 538824  film told chronolog format stori told four dif...
# 538825  film told chronolog format stori told four dif...
# 538826  film told chronolog format stori told four dif...
# 538827  film told chronolog format stori told four dif...
#
# [538828 rows x 5 columns]

# %%
df['review'].replace('', np.nan, inplace=True)
df.dropna(subset=['review'], inplace=True)

df['synopsis'].replace('', np.nan, inplace=True)
df.dropna(subset=['synopsis'], inplace=True)

# %%
df.insert(0,'index',df.index.values)

# %%
df
# Out:
#          index   movie_id    user_id  is_spoiler  \
# 0            0  tt0111161  ur1898687        True
# 1            1  tt0111161  ur0842118        True
# 2            2  tt0111161  ur1285640        True
# 3            3  tt0111161  ur1003471        True
# 4            4  tt0111161  ur0226855        True
# ...        ...        ...        ...         ...
# 538823  538823  tt0139239  ur0100166       False
# 538824  538824  tt0139239  ur0021767       False
# 538825  538825  tt0139239  ur0392750       False
# 538826  538826  tt0139239  ur0349105       False
# 538827  538827  tt0139239  ur0156431       False
#
#                                                    review  \
# 0       oscar year shawshank redempt written direct fr...
# 1       shawshank redempt without doubt one brilliant ...
# 2       believ film best stori ever told film tell rob...
# 3       yes spoiler film emot impact find hard write c...
# 4       heart extraordinari movi brilliant indel perfo...
# ...                                                   ...
# 538823  go wise fast pure entertain assembl except cas...
# 538824  well shall say fun rate three plotlin origin o...
# 538825  go best movi ever seen seen lot movi read revi...
# 538826  call teenag version pulp fiction whatev want p...
# 538827  movi made doubt sucker mtv faith mani care any...
#
#                                                  synopsis
# 0       andi dufresn tim robbin banker main convict mu...
# 1       andi dufresn tim robbin banker main convict mu...
# 2       andi dufresn tim robbin banker main convict mu...
# 3       andi dufresn tim robbin banker main convict mu...
# 4       andi dufresn tim robbin banker main convict mu...
# ...                                                   ...
# 538823  film told chronolog format stori told four dif...
# 538824  film told chronolog format stori told four dif...
# 538825  film told chronolog format stori told four dif...
# 538826  film told chronolog format stori told four dif...
# 538827  film told chronolog format stori told four dif...
#
# [538827 rows x 6 columns]

# %%
import gensim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18952\1427573704.py in <module>
# ----> 1 import gensim
#
# ~\anaconda3\envs\juunho\lib\site-packages\gensim\__init__.py in <module>
#       9 import logging
#      10
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      12
#      13
#
# ~\anaconda3\envs\juunho\lib\site-packages\gensim\corpora\__init__.py in <module>
#       4
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       7
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#
# ~\anaconda3\envs\juunho\lib\site-packages\gensim\corpora\indexedcorpus.py in <module>
#      12 import numpy
#      13
# ---> 14 from gensim import interfaces, utils
#      15
#      16 logger = logging.getLogger(__name__)
#
# ~\anaconda3\envs\juunho\lib\site-packages\gensim\interfaces.py in <module>
#      17 import logging
#      18
# ---> 19 from gensim import utils, matutils
#      20
#      21
#
# ~\anaconda3\envs\juunho\lib\site-packages\gensim\matutils.py in <module>
#      17 import numpy as np
#      18 import scipy.sparse
# ---> 19 from scipy.stats import entropy
#      20 import scipy.linalg
#      21 from scipy.linalg.lapack import get_lapack_funcs
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\__init__.py in <module>
#     439 """
#     440
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\stats.py in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\distributions.py in <module>
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#       9
#      10 from . import _continuous_distns
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\_distn_infrastructure.py in <module>
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      25
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\optimize\__init__.py in <module>
#     409 from .nonlin import *
#     410 from .slsqp import fmin_slsqp
# --> 411 from ._nnls import nnls
#     412 from ._basinhopping import basinhopping
#     413 from ._linprog import linprog, linprog_verbose_callback
#
# ImportError: DLL load failed: 지정된 모듈을 찾을 수 없습니다.

# %%
import gensim.corpora as corpora
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18972\931978181.py in <module>
# ----> 1 import gensim.corpora as corpora
#
# ~\anaconda3\envs\juunho\lib\site-packages\gensim\__init__.py in <module>
#       4 """
#       5
# ----> 6 from gensim import parsing, matutils, interfaces, corpora, models, similarities, summarization, utils  # noqa:F401
#       7 import logging
#       8
#
# ~\anaconda3\envs\juunho\lib\site-packages\gensim\matutils.py in <module>
#      19 import numpy as np
#      20 import scipy.sparse
# ---> 21 from scipy.stats import entropy
#      22 import scipy.linalg
#      23 from scipy.linalg.lapack import get_lapack_funcs
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\__init__.py in <module>
#     439 """
#     440
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\stats.py in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\distributions.py in <module>
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#       9
#      10 from . import _continuous_distns
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\stats\_distn_infrastructure.py in <module>
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      25
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#
# ~\anaconda3\envs\juunho\lib\site-packages\scipy\optimize\__init__.py in <module>
#     409 from .nonlin import *
#     410 from .slsqp import fmin_slsqp
# --> 411 from ._nnls import nnls
#     412 from ._basinhopping import basinhopping
#     413 from ._linprog import linprog, linprog_verbose_callback
#
# ImportError: DLL load failed: 지정된 모듈을 찾을 수 없습니다.

# %%
# Create Dictionary
id2word = corpora.Dictionary(df)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18972\2271017041.py in <module>
#       1 # Create Dictionary
# ----> 2 id2word = corpora.Dictionary(data_ready)
#       3
#       4 # Create Corpus: Term Document Frequency
#       5 corpus = [id2word.doc2bow(text) for text in data_ready]
#
# NameError: name 'corpora' is not defined

# %%
def get_topic_words(token_lists, labels, k=None):
    """
    get top words within each topic from clustering results
    """
    if k is None:
        k = len(np.unique(labels))
    topics = ['' for _ in range(k)]
    for i, c in enumerate(token_lists):
        topics[labels[i]] += (' ' + ' '.join(c))
    word_counts = list(map(lambda x: Counter(x.split()).items(), topics))
    # get sorted word counts
    word_counts = list(map(lambda x: sorted(x, key=lambda x: x[1], reverse=True), word_counts))
    # get topics
    topics = list(map(lambda x: list(map(lambda x: x[0], x[:10])), word_counts))

    return topics

# %%
df_1 = df.iloc[1:250000]
df_2 = df.iloc[250000:]

# %%
similarityValue = []

for i in tqdm(range(df_1.count()[0])):
    sentence_1 = nlp(df_1.iloc[i][3])
    sentence_2 = nlp(df_1.iloc[i][4])
    similarityValue.append(sentence_1.similarity(sentence_2))

df_1['Similarity'] = similarityValue

# %%
similarityValue = []

for i in tqdm(range(df_2.count()[0])):
    sentence_1 = nlp(df_2.iloc[i][3])
    sentence_2 = nlp(df_2.iloc[i][4])
    similarityValue.append(sentence_1.similarity(sentence_2))

df_2['Similarity'] = similarityValue
