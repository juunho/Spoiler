# %%
import pandas as pd
import json
import re
import os
import sys
import numpy as np
from nltk.tokenize import sent_tokenize
import random
pd.options.display.float_format = '{:,}'.format
random.seed(2021)

# %% [markdown]
# ### Data Load

# %%
df_raw = pd.read_json('IMDB_reviews.json', lines=True)
df_raw.shape
# Out:
# (573913, 7)

# %% [markdown]
# ### Review Filtering

# %%
# review filtering
df_review = df_raw.groupby('movie_id').count().sort_values(by='user_id', ascending = False)
df_review = df_review[df_review['review_date'] > 100]

df_list = df_review.index.values.tolist()

df_raw = df_raw[df_raw['movie_id'].isin(df_list)]
df_raw.shape
# Out:
# (562076, 7)

# %%
# null replace
df_raw['review_text'].replace('', np.nan, inplace=True)
df_raw.dropna(subset=['review_text'], inplace=True)
df_raw.shape
# Out:
# (562076, 7)

# %%
df_raw['Key'] = df_raw['movie_id'].map(str) + "_" + df_raw['user_id'].map(str)
#df_raw.drop(columns = ['review_date','review_summary','text_count'], inplace = True)

# %% [markdown]
# ### Similarity Combine

# %%
# Similarity Data
df1 = pd.read_csv('IMDB/dataset/sim1-spacy-pre-unq.csv')
df2 = pd.read_csv('IMDB/dataset/sim2-spacy-pre-unq.csv')

df = pd.concat([df1,df2], ignore_index=True)
df.shape
# Out:
# (257277, 8)

# %%
df.drop(columns = ['review','summary','synopsis'], inplace = True)

# %%
df['Key'] = df['movie_id'].map(str) + "_" + df['user_id'].map(str)

# %%
df.drop(columns = ['movie_id','user_id','is_spoiler'], inplace = True)
df
# Out:
#               summary_sim       synopsis_sim                   Key
# 0      0.8182528627370624 0.9379999551535706   tt0111161_ur6574726
# 1      0.8248598156132173 0.9410306515057832  tt0111161_ur31182745
# 2      0.8286599404831738 0.9451207633340328   tt0111161_ur9871443
# 3      0.8536536626202199  0.929594141329498  tt0111161_ur23169472
# 4      0.7727762898072235 0.8943991748293878  tt0111161_ur34426359
# ...                   ...                ...                   ...
# 257272 0.7507024106067787 0.7507024106067787   tt0139239_ur0415521
# 257273 0.7608688119019157 0.7608688119019157   tt0139239_ur0100166
# 257274 0.7717965122266363 0.7717965122266363   tt0139239_ur0021767
# 257275 0.7526294445454874 0.7526294445454874   tt0139239_ur0349105
# 257276 0.8375494060841269 0.8375494060841269   tt0139239_ur0156431
#
# [257277 rows x 3 columns]

# %%
df_raw
# Out:
#              review_date   movie_id    user_id  is_spoiler  \
# 0       10 February 2006  tt0111161  ur1898687        True
# 1       6 September 2000  tt0111161  ur0842118        True
# 2          3 August 2001  tt0111161  ur1285640        True
# 3       1 September 2002  tt0111161  ur1003471        True
# 4            20 May 2004  tt0111161  ur0226855        True
# ...                  ...        ...        ...         ...
# 573908     8 August 1999  tt0139239  ur0100166       False
# 573909      31 July 1999  tt0139239  ur0021767       False
# 573910      20 July 1999  tt0139239  ur0392750       False
# 573911      11 June 1999  tt0139239  ur0349105       False
# 573912        3 May 1999  tt0139239  ur0156431       False
#
#                                               review_text  rating  \
# 0       In its Oscar year, Shawshank Redemption (writt...      10
# 1       The Shawshank Redemption is without a doubt on...      10
# 2       I believe that this film is the best story eve...       8
# 3       **Yes, there are SPOILERS here**This film has ...      10
# 4       At the heart of this extraordinary movie is a ...       8
# ...                                                   ...     ...
# 573908  Go is wise, fast and pure entertainment. Assem...      10
# 573909  Well, what shall I say. this one´s fun at any ...       9
# 573910  Go is the best movie I have ever seen, and I'v...      10
# 573911  Call this 1999 teenage version of Pulp Fiction...       3
# 573912  Why was this movie made? No doubt to sucker in...       2
#
#                                        review_summary                  Key
# 0       A classic piece of unforgettable film-making.  tt0111161_ur1898687
# 1          Simply amazing. The best film of the 90's.  tt0111161_ur0842118
# 2                    The best story ever told on film  tt0111161_ur1285640
# 3                          Busy dying or busy living?  tt0111161_ur1003471
# 4              Great story, wondrously told and acted  tt0111161_ur0226855
# ...                                               ...                  ...
# 573908            The best teen movie of the nineties  tt0139239_ur0100166
# 573909                             Go - see the movie  tt0139239_ur0021767
# 573910             It's the best movie I've ever seen  tt0139239_ur0392750
# 573911                   Haven't we seen this before?  tt0139239_ur0349105
# 573912                         Go doesn't go anywhere  tt0139239_ur0156431
#
# [562076 rows x 8 columns]

# %%
df_raw = pd.merge(df_raw, df, how='inner', on ='Key')

# %%
df_raw
# Out:
#             review_date   movie_id     user_id  is_spoiler  \
# 0        9 October 2005  tt0111161   ur6574726        True
# 1       4 February 2012  tt0111161  ur31182745        True
# 2       24 October 2008  tt0111161   ur9871443        True
# 3           1 June 2010  tt0111161  ur23169472        True
# 4          16 July 2013  tt0111161  ur34426359        True
# ...                 ...        ...         ...         ...
# 257272   14 August 1999  tt0139239   ur0415521       False
# 257273    8 August 1999  tt0139239   ur0100166       False
# 257274     31 July 1999  tt0139239   ur0021767       False
# 257275     11 June 1999  tt0139239   ur0349105       False
# 257276       3 May 1999  tt0139239   ur0156431       False
#
#                                               review_text  rating  \
# 0       I have been a fan of this movie for a long tim...       9
# 1       I made my account on IMDb Just to Rate this mo...      10
# 2       A friend of mine listed "The Shawshank Redempt...      10
# 3       To tell the truth, I am speechless. I am a you...      10
# 4       Wow! what a film this baby is and yes this fil...      10
# ...                                                   ...     ...
# 257272  This type of movie is one that I would not ord...       9
# 257273  Go is wise, fast and pure entertainment. Assem...      10
# 257274  Well, what shall I say. this one´s fun at any ...       9
# 257275  Call this 1999 teenage version of Pulp Fiction...       3
# 257276  Why was this movie made? No doubt to sucker in...       2
#
#                                    review_summary                   Key  \
# 0                       This Movie Saved My Life.   tt0111161_ur6574726
# 1                    Movie you can see 1000 times  tt0111161_ur31182745
# 2                        The Shawshank Redemption   tt0111161_ur9871443
# 3         Blatantly Simple, yet Utterly Beautiful  tt0111161_ur23169472
# 4       Great films come only once in a blue moon  tt0111161_ur34426359
# ...                                           ...                   ...
# 257272                                 GO see it!   tt0139239_ur0415521
# 257273        The best teen movie of the nineties   tt0139239_ur0100166
# 257274                         Go - see the movie   tt0139239_ur0021767
# 257275               Haven't we seen this before?   tt0139239_ur0349105
# 257276                     Go doesn't go anywhere   tt0139239_ur0156431
#
#               summary_sim       synopsis_sim
# 0      0.8182528627370624 0.9379999551535706
# 1      0.8248598156132173 0.9410306515057832
# 2      0.8286599404831738 0.9451207633340328
# 3      0.8536536626202199  0.929594141329498
# 4      0.7727762898072235 0.8943991748293878
# ...                   ...                ...
# 257272 0.7507024106067787 0.7507024106067787
# 257273 0.7608688119019157 0.7608688119019157
# 257274 0.7717965122266363 0.7717965122266363
# 257275 0.7526294445454874 0.7526294445454874
# 257276 0.8375494060841269 0.8375494060841269
#
# [257277 rows x 10 columns]

# %%
df_raw.summary_sim = df_raw.summary_sim.round(3)

# %%
df_raw.synopsis_sim = df_raw.synopsis_sim.round(3)

# %%
data = []
# For each of the samples...
for index, row in df_raw.iterrows():

    # Piece it together...    
    combined = ""
    
    #combined += "The ID of this item is {:}, ".format(row["Clothing ID"])
    combined += "My review is {:} similar to the summary. ".format(row["summary_sim"])
    
    combined += "And {:} similar to the ending. ".format(row["synopsis_sim"])
       
    # Finally, append the review the text!
    data.append(combined)
    
df = pd.DataFrame(data, columns=['combined'])
df_raw = pd.concat([df_raw,df], axis=1)


print('DONE.')
# Out:
# DONE.

# %%
df
# Out:
#                                                  combined
# 0       My review is 0.818 similar to the summary. And...
# 1       My review is 0.825 similar to the summary. And...
# 2       My review is 0.829 similar to the summary. And...
# 3       My review is 0.854 similar to the summary. And...
# 4       My review is 0.773 similar to the summary. And...
# ...                                                   ...
# 257272  My review is 0.751 similar to the summary. And...
# 257273  My review is 0.761 similar to the summary. And...
# 257274  My review is 0.772 similar to the summary. And...
# 257275  My review is 0.753 similar to the summary. And...
# 257276  My review is 0.838 similar to the summary. And...
#
# [257277 rows x 1 columns]

# %%
df_raw.tail(50)
# Out:
#               review_date   movie_id    user_id  is_spoiler  \
# 257227       12 June 2015  tt0139239  ur1234929       False
# 257228   14 November 2004  tt0139239  ur3151829       False
# 257229      31 March 2003  tt0139239  ur2326727       False
# 257230      23 April 1999  tt0139239  ur0299959       False
# 257231      18 April 1999  tt0139239  ur0244097       False
# 257232      17 April 1999  tt0139239  ur0161832       False
# 257233       3 March 2002  tt0139239  ur1518199       False
# 257234   25 November 2001  tt0139239  ur0448368       False
# 257235     8 October 2001  tt0139239  ur1216786       False
# 257236      28 March 2001  tt0139239  ur0564402       False
# 257237    17 January 2001  tt0139239  ur0897109       False
# 257238   28 December 2000  tt0139239  ur0112510       False
# 257239  16 September 2000  tt0139239  ur0316657       False
# 257240      5 August 2000  tt0139239  ur0480532       False
# 257241       10 July 2000  tt0139239  ur0794074       False
# 257242       23 June 2000  tt0139239  ur0774772       False
# 257243        4 June 2000  tt0139239  ur0158415       False
# 257244   11 February 2000  tt0139239  ur0499632       False
# 257245    31 January 2000  tt0139239  ur0506531       False
# 257246   15 December 1999  tt0139239  ur0450940       False
# 257247    9 December 1999  tt0139239  ur0223712       False
# 257248   12 November 1999  tt0139239  ur0501260       False
# 257258  This is exactly how human traffic should've be...       9
# 257259  Before I went to see this film I had no idea w...       8
# 257260  This film is great fun.  After the initial 'gu...       8
# 257261  This film is gripping right from the start and...       8
# 257262  'Go' starts as all good movies should, in a pl...      10
# 257263  This movie provided a great experience even if...      10
# 257264  I knew nothing of this film before i saw it, i...       8
# 257265  Very crisp and entertaining complication-story...       9
# 257266  My husband and I were probably twice as old as...       8
# 257267  'Go' is a non-serious version of 'Pulp Fiction...       9
# 257268  It's time to acknowledge for once that Pulp Fi...      10
# 257269  Not bad, not bad at all.  I am a sucker for a ...       9
# 257270  I think this movie was under-appreciated by Am...      10
# 257271  A brilliant, fast paced, hilarious, suspensefu...      10
# 257272  This type of movie is one that I would not ord...       9
# 257273  Go is wise, fast and pure entertainment. Assem...      10
# 257274  Well, what shall I say. this one´s fun at any ...       9
# 257275  Call this 1999 teenage version of Pulp Fiction...       3
# 257276  Why was this movie made? No doubt to sucker in...       2
#
#                                            review_summary  \
# 257227                                        Typical 90s
# 257228      Permanently altered Paramount-logo perception
# 257229                       The Independent Spirit Rises
# 257230                                          Morality?
# 257231                           "Go" more like "Blow"...
# 257232  Edited and acted well; but I can't believe thi...
# 257233            Drugs, Sex, Violence, and Family Circus
# 257234                             Pretension is its flaw
# 257235                          A rip-off of Pulp Fiction
# 257236                         Four reasons to watch "Go"
# 257237        bad, full of clichés, completely uninspired
# 257238                                          Go see Go
# 257239                    Pulp Fiction's witty descendant
# 257240                                     Disappointing.
# 257241      Pointless would-be comedy not worth watching.
# 257242  We've all seen Pulp Fiction, it was a good mov...
# 257243                                Surprisingly boring
# 257244                        Not a classic, but not bad.
# 257245                                        "Go" sucked
# 257246                                           Bizarre!
# 257247                                   Film of the year
# 257248                                     What a trip...
# 257249                                         Great Idea
# 257250                        Invigorating rollercoaster.
# 257251  A "Pulp Fiction" with teen idols. Who would ha...
# 257252  I liked this the first time, when it was calle...
# 257253                                        Great movie
# 257254                                  Go holds it's own
# 257255                                    Surprising film
# 257256     The film that capped a great summer of movies.
# 257257                   An inspired fun ride of a movie.
# 257258                       Human Traffic, with a plot!!
# 257259                                      Huge Fun Film
# 257260                                Go vs Human Traffic
# 257261       Go... you must Go and watch this great film!
# 257262                 'Go' hits all the right buttons...
# 257263             Funny, suspenseful and nice to look at
# 257264                                      nice surprise
# 257265                    Entertaining complication-story
# 257266                                 My advice is "Go!"
# 257267          'Pulp Fiction' with a sense of humor.....
# 257268  Go gave me just what I wanted 103 minutes of a...
# 257269              Did somebody say 'Quentin Tarantino'?
# 257270                innovative and rockin'...I love Go!
# 257271  For Every Drug Deal There's More Than One Stor...
# 257272                                         GO see it!
# 257273                The best teen movie of the nineties
# 257274                                 Go - see the movie
# 257275                       Haven't we seen this before?
# 257276                             Go doesn't go anywhere
#
#                         Key  summary_sim  synopsis_sim  \
# 257227  tt0139239_ur1234929        0.825         0.825
# 257228  tt0139239_ur3151829        0.764         0.764
# 257229  tt0139239_ur2326727        0.754         0.754
# 257240  My review is 0.815 similar to the summary. And...
# 257241  My review is 0.836 similar to the summary. And...
# 257242  My review is 0.725 similar to the summary. And...
# 257243  My review is 0.79 similar to the summary. And ...
# 257244  My review is 0.732 similar to the summary. And...
# 257245  My review is 0.743 similar to the summary. And...
# 257246  My review is 0.769 similar to the summary. And...
# 257247  My review is 0.745 similar to the summary. And...
# 257248  My review is 0.778 similar to the summary. And...
# 257249  My review is 0.773 similar to the summary. And...
# 257250  My review is 0.756 similar to the summary. And...
# 257251  My review is 0.767 similar to the summary. And...
# 257252  My review is 0.607 similar to the summary. And...
# 257253  My review is 0.716 similar to the summary. And...
# 257254  My review is 0.77 similar to the summary. And ...
# 257255  My review is 0.722 similar to the summary. And...
# 257256  My review is 0.782 similar to the summary. And...
# 257257  My review is 0.724 similar to the summary. And...
# 257258  My review is 0.77 similar to the summary. And ...
# 257259  My review is 0.755 similar to the summary. And...
# 257260  My review is 0.787 similar to the summary. And...
# 257261  My review is 0.83 similar to the summary. And ...
# 257262  My review is 0.82 similar to the summary. And ...
# 257263  My review is 0.743 similar to the summary. And...
# 257264  My review is 0.753 similar to the summary. And...
# 257265  My review is 0.808 similar to the summary. And...
# 257266  My review is 0.771 similar to the summary. And...
# 257267  My review is 0.783 similar to the summary. And...
# 257268  My review is 0.788 similar to the summary. And...
# 257269  My review is 0.843 similar to the summary. And...
# 257270  My review is 0.742 similar to the summary. And...
# 257271  My review is 0.792 similar to the summary. And...
# 257272  My review is 0.751 similar to the summary. And...
# 257273  My review is 0.761 similar to the summary. And...
# 257274  My review is 0.772 similar to the summary. And...
# 257275  My review is 0.753 similar to the summary. And...
# 257276  My review is 0.838 similar to the summary. And...

# %%
df_raw['text'] = df_raw.review_text.map(str) + df_raw.combined.map(str)

# %% [markdown]
# ### Data Preprocessing

# %%
# column rename
df_raw['is_spoiler']= df_raw['is_spoiler'].replace([True,False],[1,0])
df_raw.rename(columns={'is_spoiler':'class'}, inplace = True)
df = df_raw[['class','text']]

# %%
# null replace
df['text'].replace('', np.nan, inplace=True)
df.dropna(subset=['text'], inplace=True)
# Out:
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df['text'].iloc[0]
# Out:
# "I have been a fan of this movie for a long time.It seems that ever time my life hits a downward spiral, I can always seem to pop this movie in, and come up with a solution to my pending problem. It somehow gives Me sense of peace and inner strength.So, It wasn't all that strange for me to pop it in when I was going through a rough patch in my marriage. I found myself identifying with many of the characters in this movie.Many of them are trapped in a world of regret and mourning, due to a mistake that had been made early on in their lives. This film gave me the strength to escape from my world of misery. And now I am able to say I, Like Andy broke out of my own personal Shawshank.My Ex isn't too happy about the divorce. But life is much better now. And I feel saved from a life of unhappiness, Due to a mistake of a marriage to early in life.Thank You Frank Durabont.Your film saved my life.My review is 0.818 similar to the summary. And 0.938 similar to the ending. "

# %%
# 
df['text'] = df['text'].apply(str)

df['text_count'] = df['text'].apply(sent_tokenize).tolist()
df['text_count'] = df['text_count'].apply(len)

df = df[df['text_count'] < 8]
df.shape
# Out:
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\User\anaconda3\envs\juunho\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# (137942, 3)

# %%
df.reset_index(drop=True, inplace=True)

# %%
#df_raw['Key'] = df_raw['movie_id'].map(str) + "_" + df_raw['user_id'].map(str)
df.drop(columns = ['text_count'], inplace = True)

# %% [markdown]
# ### Balancing

# %%
df_non = df[df['class'] == 0]
df_spoiler = df[df['class'] == 1]
print("nonspoiler:", len(df_non))
print("spoiler:", len(df_spoiler))
# Out:
# nonspoiler: 114721
# spoiler: 23221

# %%
df_non = df_non.sample(frac =.5)
print("weight-decreased nonspoiler:", len(df_non))
print("spoiler:", len(df_spoiler))
print("balanced total:", len(df_non)+len(df_spoiler))
# Out:
# weight-decreased nonspoiler: 57360
# spoiler: 23221
# balanced total: 80581

# %% [markdown]
# ### Holdout

# %%
# 70/10/20 train/val/test
df_train_non = df_non.sample(frac = .70)
df_non = df_non.drop(df_train_non.index)
df_train_spoiler = df_spoiler.sample(frac = .70)
df_spoiler = df_spoiler.drop(df_train_spoiler.index)

# use 33% of the remaining for validation (which is 10% of whole dataset)
df_dev_non = df_non.sample(frac = .333)
df_non = df_non.drop(df_dev_non.index)
df_dev_spoiler = df_spoiler.sample(frac = .333)
df_spoiler = df_spoiler.drop(df_dev_spoiler.index)

# use all of the remaining for test (which is 20% of whole dataset)
df_test_non = df_non
df_test_spoiler = df_spoiler

# %%
# merge and shuffle

df_train = pd.concat([df_train_non, df_train_spoiler])
df_train = df_train.sample(frac=1).reset_index(drop=True)

df_dev = pd.concat([df_dev_non, df_dev_spoiler])
df_dev = df_dev.sample(frac=1).reset_index(drop=True)

df_test = pd.concat([df_test_non, df_test_spoiler])
df_test = df_test.sample(frac=1).reset_index(drop=True)

print("train:",len(df_train))
print("dev:",len(df_dev))
print("test:",len(df_test))
print("all:",len(df_train)+len(df_dev)+len(df_test))
# Out:
# train: 56407
# dev: 8050
# test: 16124
# all: 80581

# %%
df_train.to_csv('IMDB/final/train_sim_sd.csv', index=False)
df_dev.to_csv('IMDB/final/dev_sim_sd.csv', index=False)
df_test.to_csv('IMDB/final/test_sim_sd.csv', index=False)

# %% [markdown]
# ### Sample

# %%
df_train_sample = df_train.sample(35000)
df_dev_sample = df_dev.sample(5000)
df_test_sample = df_test.sample(10000)

# %%
df_train_sample.to_csv('IMDB/final_sample/train_sim_sd.csv', index=False)
df_dev_sample.to_csv('IMDB/final_sample/dev_sim_sd.csv', index=False)
df_test_sample.to_csv('IMDB/final_sample/test_sim_sd.csv', index=False)
